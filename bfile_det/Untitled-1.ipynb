# %%
with open('./additional_bexe/[.exe', 'rb') as f:
    lines = f.read()

print(lines)
# bytes = lines.encode('UTF-8')
bytearray = bytearray(lines)
print(bytearray)
# Out:
# b'MZ\x90\x00\x03\x00\x00\x00\x04\x00\x00\x00\xff\xff\x00\x00\xb8\x00\x00\x00\x00\x00\x00\x00@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80\x00\x00\x00\x0e\x1f\xba\x0e\x00\xb4\t\xcd!\xb8\x01L\xcd!This program cannot be run in DOS mode.\r\r\n$\x00\x00\x00\x00\x00\x00\x00PE\x00\x00d\x86\n\x00\x00\x00\x00\x00\x00\x14\x01\x00N\x00\x00\x00\xf0\x00&\x02\x0b\x02\x02$\x00\xc0\x00\x00\x00\x10\x01\x00\x00\x18\x00\x00\x00\x10\x00\x00\x00\x10\x00\x00\x00\x00@\x00\x01\x00\x00\x00\x00\x10\x00\x00\x00\x02\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\x05\x00\x02\x00\x00\x00\x00\x00\x00\x90\x01\x00\x00\x04\x00\x00\xdd\x94\x01\x00\x03\x00\x00\x80\x00\x00 \x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00`\x01\x00\xcc\t\x00\x00\x00p\x01\x00\xe8\x04\x00\x00\x00 \x01\x00`\x06\x00\x
# ...

# %%
import random
import matplotlib.pyplot as plt

h_count = 0
t_count = 0

probs = []

for i in range(1000):
    if random.randint(0, 1) == 0:
        t_count += 1
    else:
        h_count += 1
    
    prob = h_count / (h_count + t_count)
    probs.append(prob)

plt.title('Law of Large Numbers')
plt.ylabel('percent heads')
plt.xlabel('iteration')
plt.axhline(y=0.5, color='r', linestyle='-')
plt.plot([i for i in range(len(probs))], probs)
